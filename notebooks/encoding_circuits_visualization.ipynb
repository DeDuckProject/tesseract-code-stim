# %% [markdown]
# # Encoding Circuits Visualization
#
# This notebook visualizes the encoding circuits from Fig. 9a and Fig. 9b using different Stim visualization methods.

# %%
from tesseract_sim.common.circuit_base import init_circuit
from tesseract_sim.encoding.encoding_manual_9a import encode_manual_fig9a
from tesseract_sim.encoding.encoding_manual_9b import encode_manual_fig9b
from tesseract_sim.noise.noise_cfg import NO_NOISE

# %% [markdown]
# ## Fig. 9a Encoding Circuit

# %%
# Create circuit for Fig 9a
circuit_9a = init_circuit(qubits=16, ancillas=7)
encode_manual_fig9a(circuit_9a, cfg=NO_NOISE)

# %%
# Standard diagram
circuit_9a.diagram()
# Out:
#  q0: -QUBIT_COORDS(0,0)-H-------------------------------@-------@-------@-------@-------@-------------X---------
#                                                         |       |       |       |       |             |
#  q1: -QUBIT_COORDS(1,0)-H-------------------------------|-@-----|-@-----|-@-----|-@-----|-@-----------|-X-------
#                                                         | |     | |     | |     | |     | |           | |
#  q2: -QUBIT_COORDS(2,0)-H-------------------------------|-|-@---|-|-@---|-|-@---|-|-@---|-|-@---------|-|-X-----
#                                                         | | |   | | |   | | |   | | |   | | |         | | |
#  q3: -QUBIT_COORDS(3,0)-H-------------------------------|-|-|-@-|-|-|-@-|-|-|-@-|-|-|-@-|-|-|-@-------|-|-|-X---
#                                                         | | | | | | | | | | | | | | | | | | | |       | | | |
# ...

# %%
# Timeline SVG visualization
circuit_9a.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 3168 1568"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L3136,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L3136,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L3136,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L3136,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L3136,320 " stroke="black"/>
# ...

# %%
# Crumble URL
circuit_9a.to_crumble_url()
# Out:
# 'https://algassert.com/crumble#circuit=Q(0,0)0;Q(1,0)1;Q(2,0)2;Q(3,0)3;Q(0,1)4;Q(1,1)5;Q(2,1)6;Q(3,1)7;Q(0,2)8;Q(1,2)9;Q(2,2)10;Q(3,2)11;Q(0,3)12;Q(1,3)13;Q(2,3)14;Q(3,3)15;Q(5,0)16;Q(5,1)17;Q(5,2)18;Q(5,3)19;Q(5,4)20;Q(5,5)21;Q(5,6)22;H_0_1_2_3_4_8_12;CX_4_20_4_5_4_6_4_7_4_20_8_21_8_9_8_10_8_11_8_21_12_22_12_13_12_14_12_15_12_22_0_16_1_17_2_18_3_19_0_4_1_5_2_6_3_7_0_8_1_9_2_10_3_11_0_12_1_13_2_14_3_15_0_16_1_17_2_18_3_19;R_18_19;H_19;CX_19_18_19_0_19_1_19_2_19_3_19_18'

# %% [markdown]
# ## Fig. 9b Encoding Circuit

# %%
# Create circuit for Fig 9b
circuit_9b = init_circuit(qubits=16, ancillas=7)
encode_manual_fig9b(circuit_9b, cfg=NO_NOISE)

# %%
# Standard diagram
circuit_9b.diagram()
# Out:
#  q0: -QUBIT_COORDS(0,0)-H-@-@-@-------------X-----@---------------------------------------------------------------
#                           | | |             |     |
#  q1: -QUBIT_COORDS(1,0)---X-|-|-X-----X-----|-@-X-|---------------------------------------------------------------
#                             | | |     |     | | | |
#  q2: -QUBIT_COORDS(2,0)---X-|-|-|-X---|---X-|-|-|-|-X-----@-------------------------------------------------------
#                           | | | | |   |   | | | | | |     |
#  q3: -QUBIT_COORDS(3,0)-H-|-|-|-|-@-@-|-@-|-|-|-|-|-|-@-X-|-------------------------------------------------------
#                           | | | |   | | | | | | | | | | | |
#  q4: -QUBIT_COORDS(0,1)---|-X-|-|-X-X-|-|-|-|-|-|-|-|-|-|-|-------------------------------------------------------
#                           |   | | |   | | | | | | | | | | |
#  q5: -QUBIT_COORDS(1,1)---|-X-X-|-|---|-X-|-|-|-|-|-|-|-|-|-------------------------------------------------------
# ...

# %%
# Timeline SVG visualization
circuit_9b.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 2784 1568"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L2752,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L2752,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L2752,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L2752,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L2752,320 " stroke="black"/>
# ...

# %%
# Crumble URL
circuit_9b.to_crumble_url()
# Out:
# 'https://algassert.com/crumble#circuit=Q(0,0)0;Q(1,0)1;Q(2,0)2;Q(3,0)3;Q(0,1)4;Q(1,1)5;Q(2,1)6;Q(3,1)7;Q(0,2)8;Q(1,2)9;Q(2,2)10;Q(3,2)11;Q(0,3)12;Q(1,3)13;Q(2,3)14;Q(3,3)15;Q(5,0)16;Q(5,1)17;Q(5,2)18;Q(5,3)19;Q(5,4)20;Q(5,5)21;Q(5,6)22;H_17_0_3_6_7;CX_0_1_6_2_0_4_6_5_0_5_6_1_3_2_7_4_3_4_7_1_3_5_7_2_17_0_1_16_17_1_0_16_17_2_3_16_17_3_2_16;H_17;M_17_16;H_17_8_11_14_15;CX_8_9_14_10_8_12_14_13_8_13_14_9_11_10_15_12_11_12_15_9_11_13_15_10_17_8_9_16_17_9_8_16_17_10_11_16_17_11_10_16;H_17;M_17_16'
